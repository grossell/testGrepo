# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ### Gregory Rossell - UI Designer

# %% [markdown]
# *I am interested in data science because I believe it will help me design better software-interfaces and provide better user-experiences for my company's analytical software products.*

# %% [markdown]
# ### The code below is to show that simple arithmetic works properly in this environment:

# %%
x = 2
y = 3
print(x + y)
# Out:
# 5

# %% [markdown]
# <hr style="border:1px solid #4599c3;">
#
# 1. Here's a shopping list:
#     * eggs
#     * corn
#     * bread
#     * bacon
#
#
#
# 2. Here's a list of vehicles:
#     1. Cars
#     2. Trucks
#     3. Motorcycles
#     4. Trains
#
#
# ~~Here is an example of strikethrough text~~
#
#
#
#
#
#
#
# <div class="alert alert-block alert-info" style="width 500px;">
# <b>Friendly reminder:</b> This is an alert to warn everyone to be on the lookout for giant ladybugs, thank you for your time.
#
#
# [For your reference](https://en.wikipedia.org/wiki/Coccinellidae#/media/File:Coccinella_magnifica01.jpg)
# </div>
